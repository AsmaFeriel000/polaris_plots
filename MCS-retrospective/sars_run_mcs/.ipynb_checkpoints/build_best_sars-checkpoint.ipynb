# %%
from pathlib import Path
import re
import pymol
import numpy as np

from rdkit import Chem

# %%
# ============================================================
# CONFIG
# ============================================================

REFERENCE_COMPLEX = Path(
    "./reference_structures/SARS-CoV-2-Mpro/complex.pdb"
)

PROJECT_ROOT = Path(".")

REFERENCE_CHAIN = "A"
TEMPLATE_CHAIN = "A"

OUTPUT_SDF = "best_sars.sdf"


# ============================================================
# METADATA PARSER
# ============================================================

def parse_metadata(metadata_path):

    data = {}

    with open(metadata_path, "r") as f:

        for line in f:

            line = line.strip()

            if line.startswith("Target ligand:"):
                data["target_ligand"] = line.split(":", 1)[1].strip()

            elif line.startswith("Template ligand:"):
                data["template_ligand"] = line.split(":", 1)[1].strip()

            elif line.startswith("Receptor:"):

                full_path = line.split(":", 1)[1].strip()

                marker = "receptors/"

                idx = full_path.find(marker)

                if idx == -1:
                    raise ValueError(
                        f"Could not find '{marker}' in:\n{full_path}"
                    )

                relative_part = full_path[idx:]

                data["receptor_relpath"] = Path("./") / relative_part

    return data


# ============================================================
# TRANSFORM APPLICATION
# ============================================================

def apply_pymol_transform(mol, matrix):

    conf = mol.GetConformer()

    transform = np.array(matrix).reshape(4, 4)

    for i in range(mol.GetNumAtoms()):

        pos = conf.GetAtomPosition(i)

        vec = np.array([pos.x, pos.y, pos.z, 1.0])

        new = transform @ vec

        conf.SetAtomPosition(
            i,
            (float(new[0]), float(new[1]), float(new[2]))
        )


# ============================================================
# ALIGN SINGLE LIGAND
# ============================================================

def align_ligand(ligand_folder, ligand_filename="best_pose.sdf"):

    ligand_folder = Path(ligand_folder)

    metadata_path = ligand_folder / "metadata.txt"

    if not metadata_path.exists():
        print(f"Skipping {ligand_folder} (no metadata)")
        return None

    metadata = parse_metadata(metadata_path)

    receptor_path = PROJECT_ROOT / metadata["receptor_relpath"]

    ligand_path = ligand_folder / ligand_filename

    if not ligand_path.exists():
        print(f"Missing ligand: {ligand_path}")
        return None

    mol = Chem.MolFromMolFile(str(ligand_path), removeHs=False)

    if mol is None:
        print(f"Failed to read ligand: {ligand_path}")
        return None

    print("\n===================================================")
    print(f"Processing {ligand_folder.name}")
    print(f"Target ligand    : {metadata['target_ligand']}")
    print(f"Template ligand  : {metadata['template_ligand']}")
    print(f"Template receptor: {receptor_path}")
    print("===================================================")

    pymol.cmd.reinitialize()

    pymol.cmd.load(str(REFERENCE_COMPLEX), "reference")
    pymol.cmd.load(str(receptor_path), "template")

    mobile_sel = f"template and chain {TEMPLATE_CHAIN} and name CA"
    target_sel = f"reference and chain {REFERENCE_CHAIN} and name CA"

    rms_before = pymol.cmd.rms_cur(mobile_sel, target_sel)
    print(f"RMSD before alignment: {rms_before:.3f} Å")

    pymol.cmd.align(mobile_sel, target_sel, quiet=0)

    rms_after = pymol.cmd.rms_cur(mobile_sel, target_sel)
    print(f"RMSD after alignment : {rms_after:.3f} Å")

    matrix = pymol.cmd.get_object_matrix("template")

    if matrix is None:
        print("No transform matrix")
        return None

    apply_pymol_transform(mol, matrix)

    mol.SetProp("_Name", metadata["target_ligand"])
    mol.SetProp("template_ligand", metadata["template_ligand"])
    mol.SetProp("template_receptor", str(receptor_path))

    return mol


# ============================================================
# NATURAL SORT (FIX FOR ligand_1, ligand_10 ISSUE)
# ============================================================

def get_ligand_index(path):
    match = re.search(r"ligand_(\d+)", path.name)
    return int(match.group(1)) if match else float("inf")


# ============================================================
# PROCESS ALL LIGANDS
# ============================================================

outputs_dir = Path("outputs")

ligand_folders = sorted(
    [f for f in outputs_dir.glob("ligand_*") if f.is_dir()],
    key=get_ligand_index
)

print(f"Found {len(ligand_folders)} ligand folders")

writer = Chem.SDWriter(OUTPUT_SDF)

success = 0
failed = 0

for folder in ligand_folders:

    try:
        mol = align_ligand(folder)

        if mol is not None:
            writer.write(mol)
            success += 1
        else:
            failed += 1

    except Exception as e:
        print(f"\nERROR in {folder}")
        print(e)
        failed += 1

writer.close()

print("\n======================================")
print("Finished")
print(f"Successful: {success}")
print(f"Failed    : {failed}")
print("======================================")

print(f"\nOutput written to: {OUTPUT_SDF}")
# Out:
# Found 93 ligand folders
#
# ===================================================
# Processing ligand_0
# Target ligand    : ligand_0
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_1
# Target ligand    : ligand_1
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_2
# Target ligand    : ligand_2
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_3
# Target ligand    : ligand_3
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_5
# Target ligand    : ligand_5
# Template ligand  : mol-323
# Template receptor: receptors/receptor-323.pdb
# ===================================================
# RMSD before alignment: 1.002 Å
#  Match: read scoring matrix.
#  Match: assigning 301 x 306 pairwise scores.
#  MatchAlign: aligning residues (301 vs 306)...
#  MatchAlign: score 1620.000
#  ExecutiveAlign: 301 atoms aligned.
#  ExecutiveRMS: 4 atoms rejected during cycle 1 (RMSD=0.41).
#  ExecutiveRMS: 5 atoms rejected during cycle 2 (RMSD=0.34).
#  ExecutiveRMS: 2 atoms rejected during cycle 3 (RMSD=0.33).
#  ExecutiveRMS: 1 atoms rejected during cycle 4 (RMSD=0.32).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.32).
#  Executive: RMSD =    0.319 (287 to 287 atoms)
# RMSD after alignment : 0.415 Å
#
# ===================================================
# Processing ligand_6
# Target ligand    : ligand_6
# Template ligand  : mol-109
# Template receptor: receptors/receptor-109.pdb
# ===================================================
# RMSD before alignment: 1.132 Å
#  Match: read scoring matrix.
#  Match: assigning 301 x 306 pairwise scores.
#  MatchAlign: aligning residues (301 vs 306)...
#  MatchAlign: score 1620.000
#  ExecutiveAlign: 301 atoms aligned.
#  ExecutiveRMS: 6 atoms rejected during cycle 1 (RMSD=0.43).
#  ExecutiveRMS: 6 atoms rejected during cycle 2 (RMSD=0.32).
#  ExecutiveRMS: 2 atoms rejected during cycle 3 (RMSD=0.30).
#  ExecutiveRMS: 1 atoms rejected during cycle 4 (RMSD=0.30).
#  Executive: RMSD =    0.297 (286 to 286 atoms)
# RMSD after alignment : 0.435 Å
#
# ===================================================
# Processing ligand_7
# Target ligand    : ligand_7
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_8
# Target ligand    : ligand_8
# Template ligand  : mol-100
# Template receptor: receptors/receptor-100.pdb
# ===================================================
# RMSD before alignment: 40.779 Å
#  Match: read scoring matrix.
#  Match: assigning 304 x 306 pairwise scores.
#  MatchAlign: aligning residues (304 vs 306)...
#  MatchAlign: score 1635.000
#  ExecutiveAlign: 304 atoms aligned.
#  ExecutiveRMS: 4 atoms rejected during cycle 1 (RMSD=1.73).
#  ExecutiveRMS: 15 atoms rejected during cycle 2 (RMSD=0.78).
#  ExecutiveRMS: 11 atoms rejected during cycle 3 (RMSD=0.66).
#  ExecutiveRMS: 8 atoms rejected during cycle 4 (RMSD=0.61).
#  ExecutiveRMS: 3 atoms rejected during cycle 5 (RMSD=0.58).
#  Executive: RMSD =    0.564 (263 to 263 atoms)
# RMSD after alignment : 1.755 Å
#
# ===================================================
# Processing ligand_9
# Target ligand    : ligand_9
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_10
# Target ligand    : ligand_10
# Template ligand  : mol-109
# Template receptor: receptors/receptor-109.pdb
# ===================================================
# RMSD before alignment: 1.132 Å
#  Match: read scoring matrix.
#  Match: assigning 301 x 306 pairwise scores.
#  MatchAlign: aligning residues (301 vs 306)...
#  MatchAlign: score 1620.000
#  ExecutiveAlign: 301 atoms aligned.
#  ExecutiveRMS: 6 atoms rejected during cycle 1 (RMSD=0.43).
#  ExecutiveRMS: 6 atoms rejected during cycle 2 (RMSD=0.32).
#  ExecutiveRMS: 2 atoms rejected during cycle 3 (RMSD=0.30).
#  ExecutiveRMS: 1 atoms rejected during cycle 4 (RMSD=0.30).
#  Executive: RMSD =    0.297 (286 to 286 atoms)
# RMSD after alignment : 0.435 Å
#
# ===================================================
# Processing ligand_11
# Target ligand    : ligand_11
# Template ligand  : mol-246
# Template receptor: receptors/receptor-246.pdb
# ===================================================
# RMSD before alignment: 41.021 Å
#  Match: read scoring matrix.
#  Match: assigning 306 x 306 pairwise scores.
#  MatchAlign: aligning residues (306 vs 306)...
#  MatchAlign: score 1646.000
#  ExecutiveAlign: 306 atoms aligned.
#  ExecutiveRMS: 12 atoms rejected during cycle 1 (RMSD=0.26).
#  ExecutiveRMS: 9 atoms rejected during cycle 2 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 3 (RMSD=0.21).
#  ExecutiveRMS: 3 atoms rejected during cycle 4 (RMSD=0.20).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.20).
#  Executive: RMSD =    0.198 (272 to 272 atoms)
# RMSD after alignment : 0.262 Å
#
# ===================================================
# Processing ligand_12
# Target ligand    : ligand_12
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_13
# Target ligand    : ligand_13
# Template ligand  : mol-246
# Template receptor: receptors/receptor-246.pdb
# ===================================================
# RMSD before alignment: 41.021 Å
#  Match: read scoring matrix.
#  Match: assigning 306 x 306 pairwise scores.
#  MatchAlign: aligning residues (306 vs 306)...
#  MatchAlign: score 1646.000
#  ExecutiveAlign: 306 atoms aligned.
#  ExecutiveRMS: 12 atoms rejected during cycle 1 (RMSD=0.26).
#  ExecutiveRMS: 9 atoms rejected during cycle 2 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 3 (RMSD=0.21).
#  ExecutiveRMS: 3 atoms rejected during cycle 4 (RMSD=0.20).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.20).
#  Executive: RMSD =    0.198 (272 to 272 atoms)
# RMSD after alignment : 0.262 Å
#
# ===================================================
# Processing ligand_14
# Target ligand    : ligand_14
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_15
# Target ligand    : ligand_15
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_16
# Target ligand    : ligand_16
# Template ligand  : mol-109
# Template receptor: receptors/receptor-109.pdb
# ===================================================
# RMSD before alignment: 1.132 Å
#  Match: read scoring matrix.
#  Match: assigning 301 x 306 pairwise scores.
#  MatchAlign: aligning residues (301 vs 306)...
#  MatchAlign: score 1620.000
#  ExecutiveAlign: 301 atoms aligned.
#  ExecutiveRMS: 6 atoms rejected during cycle 1 (RMSD=0.43).
#  ExecutiveRMS: 6 atoms rejected during cycle 2 (RMSD=0.32).
#  ExecutiveRMS: 2 atoms rejected during cycle 3 (RMSD=0.30).
#  ExecutiveRMS: 1 atoms rejected during cycle 4 (RMSD=0.30).
#  Executive: RMSD =    0.297 (286 to 286 atoms)
# RMSD after alignment : 0.435 Å
#
# ===================================================
# Processing ligand_17
# Target ligand    : ligand_17
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_18
# Target ligand    : ligand_18
# Template ligand  : mol-690
# Template receptor: receptors/receptor-690.pdb
# ===================================================
# RMSD before alignment: 0.955 Å
#  Match: read scoring matrix.
#  Match: assigning 301 x 306 pairwise scores.
#  MatchAlign: aligning residues (301 vs 306)...
#  MatchAlign: score 1620.000
#  ExecutiveAlign: 301 atoms aligned.
#  ExecutiveRMS: 6 atoms rejected during cycle 1 (RMSD=0.47).
#  ExecutiveRMS: 10 atoms rejected during cycle 2 (RMSD=0.38).
#  ExecutiveRMS: 5 atoms rejected during cycle 3 (RMSD=0.35).
#  ExecutiveRMS: 1 atoms rejected during cycle 4 (RMSD=0.34).
#  Executive: RMSD =    0.340 (279 to 279 atoms)
# RMSD after alignment : 0.470 Å
#
# ===================================================
# Processing ligand_19
# Target ligand    : ligand_19
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_20
# Target ligand    : ligand_20
# Template ligand  : mol-23
# Template receptor: receptors/receptor-23.pdb
# ===================================================
# RMSD before alignment: 41.025 Å
#  Match: read scoring matrix.
#  Match: assigning 306 x 306 pairwise scores.
#  MatchAlign: aligning residues (306 vs 306)...
#  MatchAlign: score 1646.000
#  ExecutiveAlign: 306 atoms aligned.
#  ExecutiveRMS: 13 atoms rejected during cycle 1 (RMSD=0.26).
#  ExecutiveRMS: 12 atoms rejected during cycle 2 (RMSD=0.22).
#  ExecutiveRMS: 9 atoms rejected during cycle 3 (RMSD=0.20).
#  ExecutiveRMS: 3 atoms rejected during cycle 4 (RMSD=0.19).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.19).
#  Executive: RMSD =    0.183 (267 to 267 atoms)
# RMSD after alignment : 0.271 Å
#
# ===================================================
# Processing ligand_21
# Target ligand    : ligand_21
# Template ligand  : mol-109
# Template receptor: receptors/receptor-109.pdb
# ===================================================
# RMSD before alignment: 1.132 Å
#  Match: read scoring matrix.
#  Match: assigning 301 x 306 pairwise scores.
#  MatchAlign: aligning residues (301 vs 306)...
#  MatchAlign: score 1620.000
#  ExecutiveAlign: 301 atoms aligned.
#  ExecutiveRMS: 6 atoms rejected during cycle 1 (RMSD=0.43).
#  ExecutiveRMS: 6 atoms rejected during cycle 2 (RMSD=0.32).
#  ExecutiveRMS: 2 atoms rejected during cycle 3 (RMSD=0.30).
#  ExecutiveRMS: 1 atoms rejected during cycle 4 (RMSD=0.30).
#  Executive: RMSD =    0.297 (286 to 286 atoms)
# RMSD after alignment : 0.435 Å
#
# ===================================================
# Processing ligand_22
# Target ligand    : ligand_22
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_23
# Target ligand    : ligand_23
# Template ligand  : mol-23
# Template receptor: receptors/receptor-23.pdb
# ===================================================
# RMSD before alignment: 41.025 Å
#  Match: read scoring matrix.
#  Match: assigning 306 x 306 pairwise scores.
#  MatchAlign: aligning residues (306 vs 306)...
#  MatchAlign: score 1646.000
#  ExecutiveAlign: 306 atoms aligned.
#  ExecutiveRMS: 13 atoms rejected during cycle 1 (RMSD=0.26).
#  ExecutiveRMS: 12 atoms rejected during cycle 2 (RMSD=0.22).
#  ExecutiveRMS: 9 atoms rejected during cycle 3 (RMSD=0.20).
#  ExecutiveRMS: 3 atoms rejected during cycle 4 (RMSD=0.19).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.19).
#  Executive: RMSD =    0.183 (267 to 267 atoms)
# RMSD after alignment : 0.271 Å
#
# ===================================================
# Processing ligand_24
# Target ligand    : ligand_24
# Template ligand  : mol-209
# Template receptor: receptors/receptor-209.pdb
# ===================================================
# RMSD before alignment: 41.023 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 9 atoms rejected during cycle 1 (RMSD=0.18).
#  ExecutiveRMS: 5 atoms rejected during cycle 2 (RMSD=0.17).
#  ExecutiveRMS: 1 atoms rejected during cycle 3 (RMSD=0.16).
#  ExecutiveRMS: 1 atoms rejected during cycle 4 (RMSD=0.16).
#  Executive: RMSD =    0.158 (289 to 289 atoms)
# RMSD after alignment : 0.187 Å
#
# ===================================================
# Processing ligand_25
# Target ligand    : ligand_25
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_26
# Target ligand    : ligand_26
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_27
# Target ligand    : ligand_27
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_28
# Target ligand    : ligand_28
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_29
# Target ligand    : ligand_29
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_30
# Target ligand    : ligand_30
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_31
# Target ligand    : ligand_31
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_32
# Target ligand    : ligand_32
# Template ligand  : mol-668
# Template receptor: receptors/receptor-668.pdb
# ===================================================
# RMSD before alignment: 40.809 Å
#  Match: read scoring matrix.
#  Match: assigning 304 x 306 pairwise scores.
#  MatchAlign: aligning residues (304 vs 306)...
#  MatchAlign: score 1635.000
#  ExecutiveAlign: 304 atoms aligned.
#  ExecutiveRMS: 4 atoms rejected during cycle 1 (RMSD=1.74).
#  ExecutiveRMS: 13 atoms rejected during cycle 2 (RMSD=0.82).
#  ExecutiveRMS: 6 atoms rejected during cycle 3 (RMSD=0.72).
#  ExecutiveRMS: 5 atoms rejected during cycle 4 (RMSD=0.69).
#  ExecutiveRMS: 9 atoms rejected during cycle 5 (RMSD=0.67).
#  Executive: RMSD =    0.636 (267 to 267 atoms)
# RMSD after alignment : 1.761 Å
#
# ===================================================
# Processing ligand_33
# Target ligand    : ligand_33
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_34
# Target ligand    : ligand_34
# Template ligand  : mol-323
# Template receptor: receptors/receptor-323.pdb
# ===================================================
# RMSD before alignment: 1.002 Å
#  Match: read scoring matrix.
#  Match: assigning 301 x 306 pairwise scores.
#  MatchAlign: aligning residues (301 vs 306)...
#  MatchAlign: score 1620.000
#  ExecutiveAlign: 301 atoms aligned.
#  ExecutiveRMS: 4 atoms rejected during cycle 1 (RMSD=0.41).
#  ExecutiveRMS: 5 atoms rejected during cycle 2 (RMSD=0.34).
#  ExecutiveRMS: 2 atoms rejected during cycle 3 (RMSD=0.33).
#  ExecutiveRMS: 1 atoms rejected during cycle 4 (RMSD=0.32).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.32).
#  Executive: RMSD =    0.319 (287 to 287 atoms)
# RMSD after alignment : 0.415 Å
#
# ===================================================
# Processing ligand_35
# Target ligand    : ligand_35
# Template ligand  : mol-73
# Template receptor: receptors/receptor-73.pdb
# ===================================================
# RMSD before alignment: 0.836 Å
#  Match: read scoring matrix.
#  Match: assigning 301 x 306 pairwise scores.
#  MatchAlign: aligning residues (301 vs 306)...
#  MatchAlign: score 1620.000
#  ExecutiveAlign: 301 atoms aligned.
#  ExecutiveRMS: 8 atoms rejected during cycle 1 (RMSD=0.36).
#  ExecutiveRMS: 3 atoms rejected during cycle 2 (RMSD=0.31).
#  ExecutiveRMS: 1 atoms rejected during cycle 3 (RMSD=0.30).
#  Executive: RMSD =    0.300 (289 to 289 atoms)
# RMSD after alignment : 0.361 Å
#
# ===================================================
# Processing ligand_36
# Target ligand    : ligand_36
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_37
# Target ligand    : ligand_37
# Template ligand  : mol-192
# Template receptor: receptors/receptor-192.pdb
# ===================================================
# RMSD before alignment: 0.959 Å
#  Match: read scoring matrix.
#  Match: assigning 300 x 306 pairwise scores.
#  MatchAlign: aligning residues (300 vs 306)...
#  MatchAlign: score 1616.000
#  ExecutiveAlign: 300 atoms aligned.
#  ExecutiveRMS: 6 atoms rejected during cycle 1 (RMSD=0.36).
#  ExecutiveRMS: 9 atoms rejected during cycle 2 (RMSD=0.30).
#  ExecutiveRMS: 3 atoms rejected during cycle 3 (RMSD=0.29).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.28).
#  ExecutiveRMS: 1 atoms rejected during cycle 5 (RMSD=0.28).
#  Executive: RMSD =    0.276 (279 to 279 atoms)
# RMSD after alignment : 0.359 Å
#
# ===================================================
# Processing ligand_38
# Target ligand    : ligand_38
# Template ligand  : mol-109
# Template receptor: receptors/receptor-109.pdb
# ===================================================
# RMSD before alignment: 1.132 Å
#  Match: read scoring matrix.
#  Match: assigning 301 x 306 pairwise scores.
#  MatchAlign: aligning residues (301 vs 306)...
#  MatchAlign: score 1620.000
#  ExecutiveAlign: 301 atoms aligned.
#  ExecutiveRMS: 6 atoms rejected during cycle 1 (RMSD=0.43).
#  ExecutiveRMS: 6 atoms rejected during cycle 2 (RMSD=0.32).
#  ExecutiveRMS: 2 atoms rejected during cycle 3 (RMSD=0.30).
#  ExecutiveRMS: 1 atoms rejected during cycle 4 (RMSD=0.30).
#  Executive: RMSD =    0.297 (286 to 286 atoms)
# RMSD after alignment : 0.435 Å
#
# ===================================================
# Processing ligand_39
# Target ligand    : ligand_39
# Template ligand  : mol-115
# Template receptor: receptors/receptor-115.pdb
# ===================================================
# RMSD before alignment: 41.030 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 10 atoms rejected during cycle 1 (RMSD=0.19).
#  ExecutiveRMS: 6 atoms rejected during cycle 2 (RMSD=0.16).
#  ExecutiveRMS: 1 atoms rejected during cycle 3 (RMSD=0.16).
#  Executive: RMSD =    0.156 (288 to 288 atoms)
# RMSD after alignment : 0.199 Å
#
# ===================================================
# Processing ligand_40
# Target ligand    : ligand_40
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_41
# Target ligand    : ligand_41
# Template ligand  : mol-127
# Template receptor: receptors/receptor-127.pdb
# ===================================================
# RMSD before alignment: 40.751 Å
#  Match: read scoring matrix.
#  Match: assigning 304 x 306 pairwise scores.
#  MatchAlign: aligning residues (304 vs 306)...
#  MatchAlign: score 1635.000
#  ExecutiveAlign: 304 atoms aligned.
#  ExecutiveRMS: 4 atoms rejected during cycle 1 (RMSD=1.72).
#  ExecutiveRMS: 16 atoms rejected during cycle 2 (RMSD=0.79).
#  ExecutiveRMS: 10 atoms rejected during cycle 3 (RMSD=0.66).
#  ExecutiveRMS: 7 atoms rejected during cycle 4 (RMSD=0.61).
#  ExecutiveRMS: 5 atoms rejected during cycle 5 (RMSD=0.58).
#  Executive: RMSD =    0.558 (262 to 262 atoms)
# RMSD after alignment : 1.751 Å
#
# ===================================================
# Processing ligand_42
# Target ligand    : ligand_42
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_43
# Target ligand    : ligand_43
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_44
# Target ligand    : ligand_44
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_45
# Target ligand    : ligand_45
# Template ligand  : mol-246
# Template receptor: receptors/receptor-246.pdb
# ===================================================
# RMSD before alignment: 41.021 Å
#  Match: read scoring matrix.
#  Match: assigning 306 x 306 pairwise scores.
#  MatchAlign: aligning residues (306 vs 306)...
#  MatchAlign: score 1646.000
#  ExecutiveAlign: 306 atoms aligned.
#  ExecutiveRMS: 12 atoms rejected during cycle 1 (RMSD=0.26).
#  ExecutiveRMS: 9 atoms rejected during cycle 2 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 3 (RMSD=0.21).
#  ExecutiveRMS: 3 atoms rejected during cycle 4 (RMSD=0.20).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.20).
#  Executive: RMSD =    0.198 (272 to 272 atoms)
# RMSD after alignment : 0.262 Å
#
# ===================================================
# Processing ligand_46
# Target ligand    : ligand_46
# Template ligand  : mol-58
# Template receptor: receptors/receptor-58.pdb
# ===================================================
# RMSD before alignment: 40.978 Å
#  Match: read scoring matrix.
#  Match: assigning 306 x 306 pairwise scores.
#  MatchAlign: aligning residues (306 vs 306)...
#  MatchAlign: score 1646.000
#  ExecutiveAlign: 306 atoms aligned.
#  ExecutiveRMS: 8 atoms rejected during cycle 1 (RMSD=0.30).
#  ExecutiveRMS: 3 atoms rejected during cycle 2 (RMSD=0.28).
#  ExecutiveRMS: 2 atoms rejected during cycle 3 (RMSD=0.27).
#  Executive: RMSD =    0.268 (293 to 293 atoms)
# RMSD after alignment : 0.306 Å
#
# ===================================================
# Processing ligand_47
# Target ligand    : ligand_47
# Template ligand  : mol-323
# Template receptor: receptors/receptor-323.pdb
# ===================================================
# RMSD before alignment: 1.002 Å
#  Match: read scoring matrix.
#  Match: assigning 301 x 306 pairwise scores.
#  MatchAlign: aligning residues (301 vs 306)...
#  MatchAlign: score 1620.000
#  ExecutiveAlign: 301 atoms aligned.
#  ExecutiveRMS: 4 atoms rejected during cycle 1 (RMSD=0.41).
#  ExecutiveRMS: 5 atoms rejected during cycle 2 (RMSD=0.34).
#  ExecutiveRMS: 2 atoms rejected during cycle 3 (RMSD=0.33).
#  ExecutiveRMS: 1 atoms rejected during cycle 4 (RMSD=0.32).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.32).
#  Executive: RMSD =    0.319 (287 to 287 atoms)
# RMSD after alignment : 0.415 Å
#
# ===================================================
# Processing ligand_48
# Target ligand    : ligand_48
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_49
# Target ligand    : ligand_49
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_50
# Target ligand    : ligand_50
# Template ligand  : mol-173
# Template receptor: receptors/receptor-173.pdb
# ===================================================
# RMSD before alignment: 0.946 Å
#  Match: read scoring matrix.
#  Match: assigning 301 x 306 pairwise scores.
#  MatchAlign: aligning residues (301 vs 306)...
#  MatchAlign: score 1620.000
#  ExecutiveAlign: 301 atoms aligned.
#  ExecutiveRMS: 8 atoms rejected during cycle 1 (RMSD=0.42).
#  ExecutiveRMS: 10 atoms rejected during cycle 2 (RMSD=0.31).
#  ExecutiveRMS: 3 atoms rejected during cycle 3 (RMSD=0.29).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.28).
#  ExecutiveRMS: 1 atoms rejected during cycle 5 (RMSD=0.28).
#  Executive: RMSD =    0.278 (277 to 277 atoms)
# RMSD after alignment : 0.419 Å
#
# ===================================================
# Processing ligand_51
# Target ligand    : ligand_51
# Template ligand  : mol-173
# Template receptor: receptors/receptor-173.pdb
# ===================================================
# RMSD before alignment: 0.946 Å
#  Match: read scoring matrix.
#  Match: assigning 301 x 306 pairwise scores.
#  MatchAlign: aligning residues (301 vs 306)...
#  MatchAlign: score 1620.000
#  ExecutiveAlign: 301 atoms aligned.
#  ExecutiveRMS: 8 atoms rejected during cycle 1 (RMSD=0.42).
#  ExecutiveRMS: 10 atoms rejected during cycle 2 (RMSD=0.31).
#  ExecutiveRMS: 3 atoms rejected during cycle 3 (RMSD=0.29).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.28).
#  ExecutiveRMS: 1 atoms rejected during cycle 5 (RMSD=0.28).
#  Executive: RMSD =    0.278 (277 to 277 atoms)
# RMSD after alignment : 0.419 Å
#
# ===================================================
# Processing ligand_52
# Target ligand    : ligand_52
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_53
# Target ligand    : ligand_53
# Template ligand  : mol-246
# Template receptor: receptors/receptor-246.pdb
# ===================================================
# RMSD before alignment: 41.021 Å
#  Match: read scoring matrix.
#  Match: assigning 306 x 306 pairwise scores.
#  MatchAlign: aligning residues (306 vs 306)...
#  MatchAlign: score 1646.000
#  ExecutiveAlign: 306 atoms aligned.
#  ExecutiveRMS: 12 atoms rejected during cycle 1 (RMSD=0.26).
#  ExecutiveRMS: 9 atoms rejected during cycle 2 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 3 (RMSD=0.21).
#  ExecutiveRMS: 3 atoms rejected during cycle 4 (RMSD=0.20).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.20).
#  Executive: RMSD =    0.198 (272 to 272 atoms)
# RMSD after alignment : 0.262 Å
#
# ===================================================
# Processing ligand_54
# Target ligand    : ligand_54
# Template ligand  : mol-246
# Template receptor: receptors/receptor-246.pdb
# ===================================================
# RMSD before alignment: 41.021 Å
#  Match: read scoring matrix.
#  Match: assigning 306 x 306 pairwise scores.
#  MatchAlign: aligning residues (306 vs 306)...
#  MatchAlign: score 1646.000
#  ExecutiveAlign: 306 atoms aligned.
#  ExecutiveRMS: 12 atoms rejected during cycle 1 (RMSD=0.26).
#  ExecutiveRMS: 9 atoms rejected during cycle 2 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 3 (RMSD=0.21).
#  ExecutiveRMS: 3 atoms rejected during cycle 4 (RMSD=0.20).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.20).
#  Executive: RMSD =    0.198 (272 to 272 atoms)
# RMSD after alignment : 0.262 Å
#
# ===================================================
# Processing ligand_55
# Target ligand    : ligand_55
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_56
# Target ligand    : ligand_56
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_57
# Target ligand    : ligand_57
# Template ligand  : mol-115
# Template receptor: receptors/receptor-115.pdb
# ===================================================
# RMSD before alignment: 41.030 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 10 atoms rejected during cycle 1 (RMSD=0.19).
#  ExecutiveRMS: 6 atoms rejected during cycle 2 (RMSD=0.16).
#  ExecutiveRMS: 1 atoms rejected during cycle 3 (RMSD=0.16).
#  Executive: RMSD =    0.156 (288 to 288 atoms)
# RMSD after alignment : 0.199 Å
#
# ===================================================
# Processing ligand_58
# Target ligand    : ligand_58
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_59
# Target ligand    : ligand_59
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_60
# Target ligand    : ligand_60
# Template ligand  : mol-100
# Template receptor: receptors/receptor-100.pdb
# ===================================================
# RMSD before alignment: 40.779 Å
#  Match: read scoring matrix.
# ...
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_78
# Target ligand    : ligand_78
# Template ligand  : mol-109
# Template receptor: receptors/receptor-109.pdb
# ===================================================
# RMSD before alignment: 1.132 Å
#  Match: read scoring matrix.
#  Match: assigning 301 x 306 pairwise scores.
#  MatchAlign: aligning residues (301 vs 306)...
#  MatchAlign: score 1620.000
#  ExecutiveAlign: 301 atoms aligned.
#  ExecutiveRMS: 6 atoms rejected during cycle 1 (RMSD=0.43).
#  ExecutiveRMS: 6 atoms rejected during cycle 2 (RMSD=0.32).
#  ExecutiveRMS: 2 atoms rejected during cycle 3 (RMSD=0.30).
#  ExecutiveRMS: 1 atoms rejected during cycle 4 (RMSD=0.30).
#  Executive: RMSD =    0.297 (286 to 286 atoms)
# RMSD after alignment : 0.435 Å
#
# ===================================================
# Processing ligand_79
# Target ligand    : ligand_79
# Template ligand  : mol-295
# Template receptor: receptors/receptor-295.pdb
# ===================================================
# RMSD before alignment: 41.055 Å
#  Match: read scoring matrix.
#  Match: assigning 306 x 306 pairwise scores.
#  MatchAlign: aligning residues (306 vs 306)...
#  MatchAlign: score 1646.000
#  ExecutiveAlign: 306 atoms aligned.
#  ExecutiveRMS: 16 atoms rejected during cycle 1 (RMSD=0.24).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.20).
#  ExecutiveRMS: 5 atoms rejected during cycle 3 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 4 (RMSD=0.18).
#  ExecutiveRMS: 1 atoms rejected during cycle 5 (RMSD=0.17).
#  Executive: RMSD =    0.173 (272 to 272 atoms)
# RMSD after alignment : 0.244 Å
#
# ===================================================
# Processing ligand_80
# Target ligand    : ligand_80
# Template ligand  : mol-100
# Template receptor: receptors/receptor-100.pdb
# ===================================================
# RMSD before alignment: 40.779 Å
#  Match: read scoring matrix.
#  Match: assigning 304 x 306 pairwise scores.
#  MatchAlign: aligning residues (304 vs 306)...
#  MatchAlign: score 1635.000
#  ExecutiveAlign: 304 atoms aligned.
#  ExecutiveRMS: 4 atoms rejected during cycle 1 (RMSD=1.73).
#  ExecutiveRMS: 15 atoms rejected during cycle 2 (RMSD=0.78).
#  ExecutiveRMS: 11 atoms rejected during cycle 3 (RMSD=0.66).
#  ExecutiveRMS: 8 atoms rejected during cycle 4 (RMSD=0.61).
#  ExecutiveRMS: 3 atoms rejected during cycle 5 (RMSD=0.58).
#  Executive: RMSD =    0.564 (263 to 263 atoms)
# RMSD after alignment : 1.755 Å
#
# ===================================================
# Processing ligand_81
# Target ligand    : ligand_81
# Template ligand  : mol-115
# Template receptor: receptors/receptor-115.pdb
# ===================================================
# RMSD before alignment: 41.030 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 10 atoms rejected during cycle 1 (RMSD=0.19).
#  ExecutiveRMS: 6 atoms rejected during cycle 2 (RMSD=0.16).
#  ExecutiveRMS: 1 atoms rejected during cycle 3 (RMSD=0.16).
#  Executive: RMSD =    0.156 (288 to 288 atoms)
# RMSD after alignment : 0.199 Å
#
# ===================================================
# Processing ligand_82
# Target ligand    : ligand_82
# Template ligand  : mol-109
# Template receptor: receptors/receptor-109.pdb
# ===================================================
# RMSD before alignment: 1.132 Å
#  Match: read scoring matrix.
#  Match: assigning 301 x 306 pairwise scores.
#  MatchAlign: aligning residues (301 vs 306)...
#  MatchAlign: score 1620.000
#  ExecutiveAlign: 301 atoms aligned.
#  ExecutiveRMS: 6 atoms rejected during cycle 1 (RMSD=0.43).
#  ExecutiveRMS: 6 atoms rejected during cycle 2 (RMSD=0.32).
#  ExecutiveRMS: 2 atoms rejected during cycle 3 (RMSD=0.30).
#  ExecutiveRMS: 1 atoms rejected during cycle 4 (RMSD=0.30).
#  Executive: RMSD =    0.297 (286 to 286 atoms)
# RMSD after alignment : 0.435 Å
#
# ===================================================
# Processing ligand_83
# Target ligand    : ligand_83
# Template ligand  : mol-23
# Template receptor: receptors/receptor-23.pdb
# ===================================================
# RMSD before alignment: 41.025 Å
#  Match: read scoring matrix.
#  Match: assigning 306 x 306 pairwise scores.
#  MatchAlign: aligning residues (306 vs 306)...
#  MatchAlign: score 1646.000
#  ExecutiveAlign: 306 atoms aligned.
#  ExecutiveRMS: 13 atoms rejected during cycle 1 (RMSD=0.26).
#  ExecutiveRMS: 12 atoms rejected during cycle 2 (RMSD=0.22).
#  ExecutiveRMS: 9 atoms rejected during cycle 3 (RMSD=0.20).
#  ExecutiveRMS: 3 atoms rejected during cycle 4 (RMSD=0.19).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.19).
#  Executive: RMSD =    0.183 (267 to 267 atoms)
# RMSD after alignment : 0.271 Å
#
# ===================================================
# Processing ligand_84
# Target ligand    : ligand_84
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_85
# Target ligand    : ligand_85
# Template ligand  : mol-192
# Template receptor: receptors/receptor-192.pdb
# ===================================================
# RMSD before alignment: 0.959 Å
#  Match: read scoring matrix.
#  Match: assigning 300 x 306 pairwise scores.
#  MatchAlign: aligning residues (300 vs 306)...
#  MatchAlign: score 1616.000
#  ExecutiveAlign: 300 atoms aligned.
#  ExecutiveRMS: 6 atoms rejected during cycle 1 (RMSD=0.36).
#  ExecutiveRMS: 9 atoms rejected during cycle 2 (RMSD=0.30).
#  ExecutiveRMS: 3 atoms rejected during cycle 3 (RMSD=0.29).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.28).
#  ExecutiveRMS: 1 atoms rejected during cycle 5 (RMSD=0.28).
#  Executive: RMSD =    0.276 (279 to 279 atoms)
# RMSD after alignment : 0.359 Å
#
# ===================================================
# Processing ligand_86
# Target ligand    : ligand_86
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_87
# Target ligand    : ligand_87
# Template ligand  : mol-323
# Template receptor: receptors/receptor-323.pdb
# ===================================================
# RMSD before alignment: 1.002 Å
#  Match: read scoring matrix.
#  Match: assigning 301 x 306 pairwise scores.
#  MatchAlign: aligning residues (301 vs 306)...
#  MatchAlign: score 1620.000
#  ExecutiveAlign: 301 atoms aligned.
#  ExecutiveRMS: 4 atoms rejected during cycle 1 (RMSD=0.41).
#  ExecutiveRMS: 5 atoms rejected during cycle 2 (RMSD=0.34).
#  ExecutiveRMS: 2 atoms rejected during cycle 3 (RMSD=0.33).
#  ExecutiveRMS: 1 atoms rejected during cycle 4 (RMSD=0.32).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.32).
#  Executive: RMSD =    0.319 (287 to 287 atoms)
# RMSD after alignment : 0.415 Å
#
# ===================================================
# Processing ligand_88
# Target ligand    : ligand_88
# Template ligand  : mol-275
# Template receptor: receptors/receptor-275.pdb
# ===================================================
# RMSD before alignment: 41.002 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 9 atoms rejected during cycle 1 (RMSD=0.22).
#  ExecutiveRMS: 6 atoms rejected during cycle 2 (RMSD=0.19).
#  ExecutiveRMS: 2 atoms rejected during cycle 3 (RMSD=0.18).
#  ExecutiveRMS: 3 atoms rejected during cycle 4 (RMSD=0.18).
#  Executive: RMSD =    0.177 (285 to 285 atoms)
# RMSD after alignment : 0.230 Å
#
# ===================================================
# Processing ligand_89
# Target ligand    : ligand_89
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_90
# Target ligand    : ligand_90
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_91
# Target ligand    : ligand_91
# Template ligand  : mol-246
# Template receptor: receptors/receptor-246.pdb
# ===================================================
# RMSD before alignment: 41.021 Å
#  Match: read scoring matrix.
#  Match: assigning 306 x 306 pairwise scores.
#  MatchAlign: aligning residues (306 vs 306)...
#  MatchAlign: score 1646.000
#  ExecutiveAlign: 306 atoms aligned.
#  ExecutiveRMS: 12 atoms rejected during cycle 1 (RMSD=0.26).
#  ExecutiveRMS: 9 atoms rejected during cycle 2 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 3 (RMSD=0.21).
#  ExecutiveRMS: 3 atoms rejected during cycle 4 (RMSD=0.20).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.20).
#  Executive: RMSD =    0.198 (272 to 272 atoms)
# RMSD after alignment : 0.262 Å
#
# ===================================================
# Processing ligand_92
# Target ligand    : ligand_92
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_93
# Target ligand    : ligand_93
# Template ligand  : mol-668
# Template receptor: receptors/receptor-668.pdb
# ===================================================
# RMSD before alignment: 40.809 Å
#  Match: read scoring matrix.
#  Match: assigning 304 x 306 pairwise scores.
#  MatchAlign: aligning residues (304 vs 306)...
#  MatchAlign: score 1635.000
#  ExecutiveAlign: 304 atoms aligned.
#  ExecutiveRMS: 4 atoms rejected during cycle 1 (RMSD=1.74).
#  ExecutiveRMS: 13 atoms rejected during cycle 2 (RMSD=0.82).
#  ExecutiveRMS: 6 atoms rejected during cycle 3 (RMSD=0.72).
#  ExecutiveRMS: 5 atoms rejected during cycle 4 (RMSD=0.69).
#  ExecutiveRMS: 9 atoms rejected during cycle 5 (RMSD=0.67).
#  Executive: RMSD =    0.636 (267 to 267 atoms)
# RMSD after alignment : 1.761 Å
#
# ===================================================
# Processing ligand_94
# Target ligand    : ligand_94
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_95
# Target ligand    : ligand_95
# Template ligand  : mol-218
# Template receptor: receptors/receptor-218.pdb
# ===================================================
# RMSD before alignment: 41.026 Å
#  Match: read scoring matrix.
#  Match: assigning 305 x 306 pairwise scores.
#  MatchAlign: aligning residues (305 vs 306)...
#  MatchAlign: score 1641.000
#  ExecutiveAlign: 305 atoms aligned.
#  ExecutiveRMS: 14 atoms rejected during cycle 1 (RMSD=0.23).
#  ExecutiveRMS: 8 atoms rejected during cycle 2 (RMSD=0.18).
#  ExecutiveRMS: 4 atoms rejected during cycle 3 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 4 (RMSD=0.17).
#  ExecutiveRMS: 2 atoms rejected during cycle 5 (RMSD=0.16).
#  Executive: RMSD =    0.162 (275 to 275 atoms)
# RMSD after alignment : 0.241 Å
#
# ===================================================
# Processing ligand_96
# Target ligand    : ligand_96
# Template ligand  : mol-109
# Template receptor: receptors/receptor-109.pdb
# ===================================================
# RMSD before alignment: 1.132 Å
#  Match: read scoring matrix.
#  Match: assigning 301 x 306 pairwise scores.
#  MatchAlign: aligning residues (301 vs 306)...
#  MatchAlign: score 1620.000
#  ExecutiveAlign: 301 atoms aligned.
#  ExecutiveRMS: 6 atoms rejected during cycle 1 (RMSD=0.43).
#  ExecutiveRMS: 6 atoms rejected during cycle 2 (RMSD=0.32).
#  ExecutiveRMS: 2 atoms rejected during cycle 3 (RMSD=0.30).
#  ExecutiveRMS: 1 atoms rejected during cycle 4 (RMSD=0.30).
#  Executive: RMSD =    0.297 (286 to 286 atoms)
# RMSD after alignment : 0.435 Å
#
# ======================================
# Finished
# Successful: 93
# Failed    : 0
# ======================================
#
# Output written to: best_sars.sdf
